# %%
import numpy as np

# %%
# Vectorized Operations

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %%
a + b
# Out:
# array([5, 7, 9])

# %%
a - b
# Out:
# array([-3, -3, -3])

# %%
a * b
# Out:
# array([ 4, 10, 18])

# %%
a / b
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
a ** b
# Out:
# array([  1,  32, 729])

# %%
# Mathematical Functions

# %%
arr = np.random.randint(0, 10, size=(2,3))
arr
# Out:
# array([[2, 5, 7],
#        [7, 6, 9]], dtype=int32)

# %%
arr.mean()
# Out:
# np.float64(6.0)

# %%
np.median(arr)
# Out:
# np.float64(6.5)

# %%
np.std(arr)
# Out:
# np.float64(2.160246899469287)

# %%
np.var(arr)
# Out:
# np.float64(4.666666666666667)

# %%
arr.sum()
# Out:
# np.int64(36)

# %%
arr.min()
# Out:
# np.int32(2)

# %%
arr.max()
# Out:
# np.int32(9)

# %%
# Broadcasting

# %%
a = np.array([1,2,3,4])

# %%
a + 10
# Out:
# array([11, 12, 13, 14])

# %%
# Axis Operations

# %%
arr = np.array([[1,2,3], 
                [4,5,6]])

# %%
np.sum(arr, axis = 0)
# Out:
# array([5, 7, 9])

# %%
np.sum(arr, axis=1)
# Out:
# array([ 6, 15])

# %%
# Random Numbers

# %%
np.random.rand(3)
# Out:
# array([0.91235689, 0.23332305, 0.26786335])

# %%
np.random.randint(0,10, size=(4,4))
# Out:
# array([[1, 1, 3, 0],
#        [1, 8, 9, 5],
#        [8, 2, 2, 0],
#        [6, 6, 3, 2]], dtype=int32)

# %%
np.random.randn(5)
# Out:
# array([-0.35368019,  1.80984573,  0.64006283,  0.4321689 , -0.262806  ])
