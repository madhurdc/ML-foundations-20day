# %%
import numpy as np

# %%
# Creating Arrays

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0,5,5)
# Out:
# array([0.  , 1.25, 2.5 , 3.75, 5.  ])

# %%
# Array Attributes
arr = np.array([[1,2,3],
                [4,5,6]])

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 6

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
# Indexing and Slicing

# %%
arr[0]
# Out:
# array([1, 2, 3])

# %%
arr[:,1]
# Out:
# array([2, 5])

# %%
arr[1,2]
# Out:
# np.int64(6)

# %%
# Reshaping Arrays

# %%
arr.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr.reshape((2,3))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
